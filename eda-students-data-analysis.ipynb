# %% [markdown]
# # **This is an EDA on student's score data.**

# %% [markdown]
# >**Checking out the location of the dataset.**

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/students-data-analysis/Students data.csv

# %% [markdown]
# >**Importing the necessary libraries.**

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns

# %% [markdown]
# >**Importing the data.**

# %%
data=pd.read_csv('/kaggle/input/students-data-analysis/Students data.csv')

# %% [markdown]
# >**Understanding the data.**

# %%
data.head()
# Out:
#      ID class  gender  race    GPA  Algebra  Calculus1  Calculus2  Statistics  \
# 0  1141     A    male     1  73.47       64         81         87          60
# 1  1142     A  female     1  71.22       57         50         51          51
# 2  1143     A  female     2  74.56       47         48         71          60
# 3  1144     A  female     1  72.89       46         72         38          60
# 4  1145     A  female     1  70.11       49         45         63          60
#
#    Probability  Measure  Functional_analysis from1 from2 from3  from4  y
# 0           74       71                   60     A     A     A      3  0
# 1           55       62                   61     B     A     A      2  0
# 2           61       68                   64     C     A     A      0  1
# 3           29       54                   51     D     A     A      0  0
# 4           66       66                   61     E     A     A      0  0

# %%
data.tail()
# Out:
#        ID class  gender  race    GPA  Algebra  Calculus1  Calculus2  \
# 100  1241     A  female     1  88.34       87         83         92
# 101  1242     B    male     1  89.84       98         77         95
# 102  1243     B    male     1  88.82       83         80         91
# 103  1244     A    male     1  86.60       92         82         91
# 104  1245     A    male     1  93.71       93         97         99
#
#      Statistics  Probability  Measure  Functional_analysis from1 from2 from3  \
# 100          98           93       86                   90     M     B     A
# 101          98           96       88                  100     A     B     A
# 102          98           93       95                   71     T     B     A
# 103          99           94       82                   78     S     B     A
# 104         100           97       90                   90     K     B     A
#
#      from4  y
# 100      0  1
# 101      0  1
# 102      0  2
# 103      0  2
# 104      0  2

# %%
data.describe()
# Out:
#                 ID        race         GPA     Algebra   Calculus1  \
# count   105.000000  105.000000  105.000000  105.000000  105.000000
# mean   1193.000000    1.790476   82.957048   76.057143   71.961905
# std      30.454885    1.673867    6.053187   11.722618   12.197039
# min    1141.000000    1.000000   63.490000   46.000000   38.000000
# 25%    1167.000000    1.000000   79.340000   67.000000   64.000000
# 50%    1193.000000    1.000000   84.110000   76.000000   73.000000
# 75%    1219.000000    1.000000   87.300000   84.000000   80.000000
# max    1245.000000    7.000000   93.710000   98.000000  100.000000
#
#         Calculus2  Statistics  Probability     Measure  Functional_analysis  \
# count  105.000000  105.000000   105.000000  105.000000           105.000000
# mean    78.942857   85.133333    83.876190   80.761905            75.323810
# std     14.997326   10.269509    10.514363   10.296119            13.003324
# ...

# %%
data.shape
# Out:
# (105, 17)

# %%
data.columns
# Out:
# Index(['ID', 'class', 'gender', 'race', 'GPA', 'Algebra', 'Calculus1',
#        'Calculus2', 'Statistics', 'Probability', 'Measure',
#        'Functional_analysis', 'from1', 'from2', 'from3', 'from4', 'y'],
#       dtype='object')

# %%
data.nunique()
# Out:
# ID                     105
# class                    2
# gender                   2
# race                     7
# GPA                    103
# Algebra                 39
# Calculus1               37
# Calculus2               38
# Statistics              30
# Probability             36
# Measure                 38
# Functional_analysis     35
# from1                   28
# from2                    2
# from3                    5
# from4                    3
# y                        3
# dtype: int64

# %%
data['Measure'].unique()
# Out:
# array([ 71,  62,  68,  54,  66,  74,  72,  78,  60,  69,  86,  57,  75,
#         76,  83,  87,  80,  81,  73,  82,  55,  79,  67,  92,  97,  84,
#         91,  89,  63,  94,  95,  99,  88,  90,  96,  85, 100,  93])

# %% [markdown]
# >**Cleaning the data.**

# %%
data.isnull().sum()
# Out:
# ID                     0
# class                  0
# gender                 0
# race                   0
# GPA                    0
# Algebra                0
# Calculus1              0
# Calculus2              0
# Statistics             0
# Probability            0
# Measure                0
# Functional_analysis    0
# from1                  0
# from2                  0
# from3                  0
# from4                  0
# y                      0
# dtype: int64

# %% [markdown]
# >**Dropping the redundant (unecessary) data.**

# %%
student = data.drop(['race','Probability'],axis=1)

# %% [markdown]
# >**Reprinting the dataset after removing unecessary data.**

# %%
student.head()
# Out:
#      ID class  gender    GPA  Algebra  Calculus1  Calculus2  Statistics  \
# 0  1141     A    male  73.47       64         81         87          60
# 1  1142     A  female  71.22       57         50         51          51
# 2  1143     A  female  74.56       47         48         71          60
# 3  1144     A  female  72.89       46         72         38          60
# 4  1145     A  female  70.11       49         45         63          60
#
#    Measure  Functional_analysis from1 from2 from3  from4  y
# 0       71                   60     A     A     A      3  0
# 1       62                   61     B     A     A      2  0
# 2       68                   64     C     A     A      0  1
# 3       54                   51     D     A     A      0  0
# 4       66                   61     E     A     A      0  0

# %% [markdown]
# >**Relationship analysis.**

# %%
corelation = student[numeric_columns].corr()
print(corelation)
# Out:
#                            ID       GPA   Algebra  Calculus1  Calculus2  \
# ID                   1.000000  0.688738  0.751647   0.502151   0.610048
# GPA                  0.688738  1.000000  0.761590   0.660560   0.803865
# Algebra              0.751647  0.761590  1.000000   0.608083   0.640578
# Calculus1            0.502151  0.660560  0.608083   1.000000   0.588929
# Calculus2            0.610048  0.803865  0.640578   0.588929   1.000000
# Statistics           0.925148  0.740903  0.759595   0.547605   0.640908
# Measure              0.635982  0.758676  0.755499   0.471347   0.658728
# Functional_analysis  0.464508  0.809451  0.572575   0.430825   0.672529
# from4               -0.112189 -0.052361 -0.078426   0.034589   0.002183
# y                    0.319634  0.292536  0.257051   0.125429   0.154947
#
#                      Statistics   Measure  Functional_analysis     from4  \
# ID                     0.925148  0.635982             0.464508 -0.112189
# ...

# %% [markdown]
# >**Generating a heatmap on the present data.**

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# >**Pairplot.**

# %%
sns.pairplot(student)

# %% [markdown]
# >**Relational plot.**

# %%
sns.relplot(x='Calculus1',y='Calculus2',hue='gender',data=student)

# %% [markdown]
# >**Histogram.**

# %%
sns.displot(student['GPA'],bins=5)

# %% [markdown]
# >**Box plot.**

# %%
sns.catplot(x='Statistics',kind='box',data=student)
